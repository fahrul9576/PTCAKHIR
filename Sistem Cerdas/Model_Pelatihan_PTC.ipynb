# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ud1Q3S3dFkftyHh1WeBD")
project = rf.workspace("fire-bf7qe").project("fire-1iktz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fire-1 in yolov8:: 100%|██████████| 5015/5015 [00:00<00:00, 6372.21it/s]

# %%
# !yolo detect train data=/content/Fire-1/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 93.2MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Import library YOLO dari ultralytics
from ultralytics import YOLO

# Load model YOLOv8 yang sudah dilatih
model = YOLO("/content/runs/detect/train/weights/best.pt")  # Path ke model hasil pelatihan

# Evaluasi model menggunakan data uji
results = model.val()

# Menampilkan metrik evaluasi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c4d2ca5df57b> in <cell line: 4>()
#       2
#       3 # Load model YOLOv8 yang sudah dilatih
# ----> 4 model = YOLO("/content/runs/detect/train/weights/best.pt")  # Path ke model hasil pelatihan
#       5
#       6 # Evaluasi model menggunakan data uji
#
# NameError: name 'YOLO' is not defined
